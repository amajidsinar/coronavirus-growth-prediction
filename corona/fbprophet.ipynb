# %%
import pandas as pd
from fbprophet import Prophet

# %%
df=pd.read_csv("Indonesia.csv")
df['cap'] = 2000

# %%
m = Prophet(growth='logistic')
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.

# %%
future = m.make_future_dataframe(periods=60)
future.tail()
# Out:
#            ds
# 75 2020-05-17
# 76 2020-05-18
# 77 2020-05-19
# 78 2020-05-20
# 79 2020-05-21

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#            ds         yhat   yhat_lower   yhat_upper
# 75 2020-05-17  1407.407721  1332.213051  1482.589877
# 76 2020-05-18  1403.109789  1322.440164  1477.833469
# 77 2020-05-19  1418.459399  1342.367335  1492.986124
# 78 2020-05-20  1439.140268  1364.340336  1509.104552
# 79 2020-05-21  1471.820512  1402.232239  1546.144996

# %%
fig1 = m.plot(forecast)
